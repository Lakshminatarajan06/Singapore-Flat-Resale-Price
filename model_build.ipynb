# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r'C:\Users\Good Day\Desktop\Project 6\preprocess_data')
df
# Out:
#         month  town  flat_type  block  street_name  storey_range  \
# 0        1990     0          0    829           13      2.397895
# 1        1990     0          0    829           13      1.609438
# 2        1990     0          0    829           13      2.397895
# 3        1990     0          0    829           13      2.079442
# 4        1990     0          2    447           13      1.609438
# ...       ...   ...        ...    ...          ...           ...
# 925784   2024    26          4   1538          571      1.609438
# 925785   2024    26          5    999          553      1.609438
# 925786   2024    26          5   2270          554      1.609438
# 925787   2024    26          5   1033          563      1.609438
# 925788   2024    26          5   2381          575      1.609438
#
#         floor_area_sqm  flat_model  lease_commence_date  resale_price  \
# 0                 31.0           7             7.589336        9000.0
# ...

# %%
df.columns
# Out:
# Index(['month', 'town', 'flat_type', 'block', 'street_name', 'storey_range',
#        'floor_area_sqm', 'flat_model', 'lease_commence_date', 'resale_price',
#        'remaining_lease', 'Flat_old'],
#       dtype='object')
